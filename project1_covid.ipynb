# %% [markdown]
# # Need a comment

# %% [markdown]
# ## Install and import the required libraries and dependencies

# %%
# Install the required libraries
# I have already installed prophet so I have commented out this line below.
#!pip install prophet

# %%
# Import the required libraries and dependencies
import pandas as pd
from prophet import Prophet
import datetime as dt
import numpy as np
# %matplotlib inline

# %%
# Store the data in a Pandas DataFrame
# Set the "Date" column as the Datetime Index.

df_mercado_trends = pd.read_csv(
    "https://static.bc-edx.com/ai/ail-v-1-0/m8/lms/datasets/google_hourly_search_trends.csv",
    index_col='Date',
    parse_dates=True
).dropna()

# Review the first and last five rows of the DataFrame
display(df_mercado_trends.head())
display(df_mercado_trends.tail())
# Out:
# C:\Users\kalas\AppData\Local\Temp\ipykernel_9684\1669825240.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_mercado_trends = pd.read_csv(
#                      Search Trends
# Date
# 2016-06-01 00:00:00             97
# 2016-06-01 01:00:00             92
# 2016-06-01 02:00:00             76
# 2016-06-01 03:00:00             60
# 2016-06-01 04:00:00             38
#                      Search Trends
# Date
# 2020-09-07 20:00:00             71
# 2020-09-07 21:00:00             83
# 2020-09-07 22:00:00             96
# 2020-09-07 23:00:00             97
# 2020-09-08 00:00:00             96

# %%
# Review the data types of the DataFrame using the info function
df_mercado_trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 37106 entries, 2016-06-01 00:00:00 to 2020-09-08 00:00:00
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Search Trends  37106 non-null  int64
# dtypes: int64(1)
# memory usage: 1.6 MB

# %%
# Slice the DataFrame to just the month of May 2020
df_may = df_mercado_trends.loc["2020-05-01":"2020-05-31"]

# Plot to visualize the data for May 2020
df_may.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df_fat_supply = pd.read_csv("Fat_Supply_Quantity_Data.csv", index_col="Country")
df_fat_supply.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 170 entries, Afghanistan to Zimbabwe
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Alcoholic Beverages           170 non-null    float64
#  1   Animal Products               170 non-null    float64
#  2   Animal fats                   170 non-null    float64
#  3   Aquatic Products, Other       170 non-null    float64
#  4   Cereals - Excluding Beer      170 non-null    float64
#  5   Eggs                          170 non-null    float64
#  6   Fish, Seafood                 170 non-null    float64
#  7   Fruits - Excluding Wine       170 non-null    float64
#  8   Meat                          170 non-null    float64
#  9   Miscellaneous                 170 non-null    float64
#  10  Milk - Excluding Butter       170 non-null    float64
#  11  Offals                        170 non-null    float64
# ...

# %%
df_fat_supply.head()
# Out:
#                      Alcoholic Beverages  Animal Products  Animal fats  \
# Country
# Afghanistan                          0.0          21.6397       6.2224
# Albania                              0.0          32.0002       3.4172
# Algeria                              0.0          14.4175       0.8972
# Angola                               0.0          15.3041       1.3130
# Antigua and Barbuda                  0.0          27.7033       4.6686
#
#                      Aquatic Products, Other  Cereals - Excluding Beer  \
# Country
# Afghanistan                              0.0                    8.0353
# Albania                                  0.0                    2.6734
# Algeria                                  0.0                    4.2035
# Angola                                   0.0                    6.5545
# Antigua and Barbuda                      0.0                    3.2153
#
#                        Eggs  Fish, Seafood  Fruits - Excluding Wine     Meat  \
# Country
# ...

# %%
df_protein_supply = pd.read_csv("Protein_Supply_Quantity_Data.csv", index_col="Country")
df_protein_supply.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 170 entries, Afghanistan to Zimbabwe
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Alcoholic Beverages           170 non-null    float64
#  1   Animal Products               170 non-null    float64
#  2   Animal fats                   170 non-null    float64
#  3   Aquatic Products, Other       170 non-null    float64
#  4   Cereals - Excluding Beer      170 non-null    float64
#  5   Eggs                          170 non-null    float64
#  6   Fish, Seafood                 170 non-null    float64
#  7   Fruits - Excluding Wine       170 non-null    float64
#  8   Meat                          170 non-null    float64
#  9   Milk - Excluding Butter       170 non-null    float64
#  10  Offals                        170 non-null    float64
#  11  Oilcrops                      170 non-null    float64
# ...

# %%
df_protein_supply.head()
# Out:
#                      Alcoholic Beverages  Animal Products  Animal fats  \
# Country
# Afghanistan                       0.0000           9.7523       0.0277
# Albania                           0.1840          27.7469       0.0711
# Algeria                           0.0323          13.8360       0.0054
# Angola                            0.6285          15.2311       0.0277
# Antigua and Barbuda               0.1535          33.1901       0.1289
#
#                      Aquatic Products, Other  Cereals - Excluding Beer  \
# Country
# Afghanistan                              0.0                   35.9771
# Albania                                  0.0                   14.2331
# Algeria                                  0.0                   26.5633
# Angola                                   0.0                   20.3882
# Antigua and Barbuda                      0.0                   10.5108
#
#                        Eggs  Fish, Seafood  Fruits - Excluding Wine     Meat  \
# Country
# ...

# %%
df_fat_protein = pd.merge(df_fat_supply, df_protein_supply, on="Country", how="outer")
df_fat_protein.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 170 entries, Afghanistan to Zimbabwe
# Data columns (total 62 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Alcoholic Beverages_x           170 non-null    float64
#  1   Animal Products_x               170 non-null    float64
#  2   Animal fats_x                   170 non-null    float64
#  3   Aquatic Products, Other_x       170 non-null    float64
#  4   Cereals - Excluding Beer_x      170 non-null    float64
#  5   Eggs_x                          170 non-null    float64
#  6   Fish, Seafood_x                 170 non-null    float64
#  7   Fruits - Excluding Wine_x       170 non-null    float64
#  8   Meat_x                          170 non-null    float64
#  9   Miscellaneous_x                 170 non-null    float64
#  10  Milk - Excluding Butter_x       170 non-null    float64
#  11  Offals_x                        170 non-null    float64
# ...

# %%
df_fat_protein[["Alcoholic Beverages_x", "Alcoholic Beverages_y"]].head()
# Out:
#                      Alcoholic Beverages_x  Alcoholic Beverages_y
# Country
# Afghanistan                            0.0                 0.0000
# Albania                                0.0                 0.1840
# Algeria                                0.0                 0.0323
# Angola                                 0.0                 0.6285
# Antigua and Barbuda                    0.0                 0.1535
